# %%
from function_lib import *

# %%
n = 1000
input_dim = 5
noise = 0.5
deg = 6
num_node = 5

base_path = change_to_parent_dir_once()
base = base_path + "/Data/Shortest_path"
train_dl, valid_dl, test_dl = load_shortest_path_setting_with_splits(
    base_dir=base,
    n=n,
    input_dim=input_dim,
    deg=deg,
    noise=noise,
    grid_width=num_node,
    seed=0,
    batch_size=32
)

for x_batch, y_batch in train_dl:
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([32, 5]) torch.Size([32, 40])

# %%
len(train_dl.dataset)
# Out:
# 800
