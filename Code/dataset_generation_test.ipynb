# %%
from function_lib import *

# %%
n = 1000
input_dim = 5
noise = 1
deg = 6
num_node = 15

base_path = change_to_parent_dir_once()
y_train, x_test, y_test, train_dl, valid_dl, test_dl = read_shortest_path_data(base_path,  n, input_dim, noise, deg, num_node)
